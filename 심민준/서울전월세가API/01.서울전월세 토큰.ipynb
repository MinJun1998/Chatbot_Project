# %%
import pandas as pd
from konlpy.tag import Okt

# %%
with open('서울전월세_전처리.csv', 'r') as file:
        text = file.read()  # 파일 내용 읽기
        print(text)
# Out:
# SGG_NM,BJDONG_NM,FLR_NO,CNTRCT_DE,RENT_GBN,RENT_AREA,RENT_GTN,RENT_FEE,BLDG_NM,BUILD_YEAR,HOUSE_GBN_NM
# 용산구,도원동,16.0,20231022,월세,32.76,1351,18,도원동삼성래미안(임대),2001,아파트
# 송파구,장지동,2.0,20231022,월세,49.93,4376,29,송파파인타운10단지,2007,아파트
# 은평구,역촌동,13.0,20231022,월세,16.12,3506,5,헤르미온,2020,연립다세대
# 강동구,강일동,12.0,20231021,월세,39.9,2938,23,강일리버파크3단지,2009,아파트
# 구로구,천왕동,7.0,20231021,월세,29.96,4159,5,천왕이펜하우스7단지,2017,아파트
# 광진구,자양동,4.0,20231020,월세,29.04,2000,85,경성아트빌,2016,연립다세대
# 구로구,천왕동,9.0,20231020,월세,59.97,9505,31,천왕연지타운1단지,2013,아파트
# 광진구,자양동,5.0,20231020,전세,31.01,23000,0,경성홈타운,2014,연립다세대
# 송파구,거여동,13.0,20231020,전세,84.89,50000,0,현대1차,1992,아파트
# 은평구,녹번동,2.0,20231020,전세,51.22,20500,0,경인에버빌(141-105),2014,연립다세대
# 동작구,동작동,4.0,20231020,전세,60.0,68000,0,이수힐스테이트,2013,아파트
# 용산구,원효로4가,22.0,20231020,전세,59.94,51800,0,강변삼성스위트,1999,아파트
# 은평구,대조동,2.0,20231020,월세,29.99,14000,22,하늘파크빌,2011,연립다세대
# 송파구,거여동,13.0,20231020,전세,39.15,3691,0,거여6단지,1997,아파트
# 강남구,역삼동,21.0,20231020,월세,59.4,20000,280,역삼래미안,2005,아파트
# ...

# %%
okt = Okt()
okt.nouns(text)
# Out:
# ['용산구',
#  '도원동',
#  '월세',
#  '도원동',
#  '삼성',
#  '래미안',
#  '임대',
#  '아파트',
#  '송파구',
#  '장지동',
#  '월세',
#  '송파',
#  '타운',
#  '단지',
#  '아파트',
#  '은평구',
#  '역촌동',
#  '월세',
#  '헤르',
#  '미온',
#  '립',
#  '다세대',
#  '강동구',
#  '강일동',
#  '월세',
#  '강일',
#  '리버',
#  '파크',
#  '단지',
#  '아파트',
#  '구로구',
#  '천왕',
#  '월세',
#  '천왕',
#  '펜',
#  '하우스',
#  '단지',
#  '아파트',
#  '광진구',
#  '자양동',
#  '월세',
#  '아트',
#  '립',
#  '다세대',
#  '구로구',
#  '천왕',
#  '월세',
#  '천왕',
#  '타운',
#  '단지',
#  '아파트',
#  '광진구',
#  '자양동',
#  '전세',
#  '홈',
#  '타운',
#  '립',
#  '다세대',
#  '송파구',
#  '거여동',
#  '전세',
#  '현대',
#  '차',
#  '아파트',
#  '은평구',
#  '녹번동',
#  '전세',
#  '경인',
#  '에버',
#  '립',
#  '다세대',
#  '동작구',
#  '작동',
#  '전세',
#  '힐스테이트',
#  '아파트',
#  '용산구',
#  '원효로',
#  '전세',
#  '강변',
#  '삼성',
#  '스',
#  '위트',
#  '아파트',
#  '은평구',
#  '대조동',
#  '월세',
#  '하늘',
#  '파크빌',
#  '립',
#  '다세대',
#  '송파구',
#  '거여동',
#  '전세',
#  '거여',
#  '단지',
#  '아파트',
#  '강남구',
#  '역삼동',
#  '월세',
#  '역삼',
#  '래미안',
#  '아파트',
#  '서초구',
#  '반포동',
#  '전세',
# ...
