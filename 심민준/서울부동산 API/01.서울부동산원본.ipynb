# %%
import requests
from urllib.parse import quote
import pandas as pd

# %%
# API 키 로드
with open('key/서울부동산key.txt') as file:
    부동산_key = file.read()

# %%
# 한번에 1000개 데이터밖에 불러오지못해서 반복문을 사용해 데이터 불러오기
a = 1
b = 1000
data = []
for i in range(26):
    base_url = f'http://openapi.seoul.go.kr:8088/{quote(부동산_key)}/json/landBizInfo/{a}/{b}/'
    url = requests.get(base_url).json()
    df = pd.DataFrame(url['landBizInfo']['row'])
    data.append(df)
    a += 1000
    b += 1000
base_url1 = f'http://openapi.seoul.go.kr:8088/{quote(부동산_key)}/json/landBizInfo/26001/26608/'
url1 = requests.get(base_url1).json()
df1 = pd.DataFrame(url1['landBizInfo']['row'])
data.append(df1)
df2 = pd.concat(data, ignore_index=True)

# %%
# 데이터 확인
df2.head()
# Out:
#          SYS_REGNO SGG_CD   BJDONG_CD SGG_NM BJDONG_NM LAND_GBN  BOBN  BUBN  \
# 0  115302022000089  11530  1153010100    구로구      신도림동        1  0337  0000
# 1  115302023000055  11530  1153010200    구로구       구로동        1  0191  0007
# 2  115302023000058  11530  1153010200    구로구       구로동        1  0725  0008
# 3  115302023000057  11530  1153010200    구로구       구로동        1  0805  0001
# 4  115302000000012  11530  1153010200    구로구       구로동        1  1263  0000
#
#                                         ADDRESS          RA_REGNO  ...  \
# 0  서울특별시 구로구 경인로 661 101동 619호(신도림동, 신도림1차푸르지오)  11500-2022-00106  ...
# 1  서울특별시 구로구 디지털로33길 11 101-1호(구로동, 에이스테크노타워8차)  11530-2023-00039  ...
# 2               서울특별시 구로구 구로동로 117  1층 일부 (구로동)  41190-2022-00036  ...
# 3                  서울특별시 구로구 도림로3길 3 1층 일부(구로동)  11530-2023-00041  ...
# 4  서울특별시 구로구 새말로 31 롯데아파트상가 108호(구로동, 신도림롯데아파트)      92420000-977  ...
#
#        CMP_NM         TELNO STS_GBN BEGIN_DE END_DE RNUM       ROAD_CD  \
# 0  라빌공인중개사사무소                   영업중                    4  115303000028
# 1  타워공인중개사사무소  02-2025-7677     영업중                    5  115304148340
# 2  아라공인중개사사무소                   영업중                    6  115303005070
# 3  한중공인중개사사무소                   영업중                    7  115304148315
# 4  롯데공인중개사사무소      855-8000     영업중                    8  115303116007
#
#   BLDG_LOC BLDG_BOBN BLDG_BUBN
# 0        0       661         0
# 1        0     00011     00000
# 2        0     00117     00000
# 3        0     00003     00000
# 4        0        31         0
#
# [5 rows x 21 columns]

# %%
# 데이터프레임 키확인
df2.keys()
# Out:
# Index(['SYS_REGNO', 'SGG_CD', 'BJDONG_CD', 'SGG_NM', 'BJDONG_NM', 'LAND_GBN',
#        'BOBN', 'BUBN', 'ADDRESS', 'RA_REGNO', 'RDEALER_NM', 'CMP_NM', 'TELNO',
#        'STS_GBN', 'BEGIN_DE', 'END_DE', 'RNUM', 'ROAD_CD', 'BLDG_LOC',
#        'BLDG_BOBN', 'BLDG_BUBN'],
#       dtype='object')

# %%
# 필요없는 컬럼 제거
df2.drop(columns=['SYS_REGNO', 'SGG_CD', 'BJDONG_CD', 'LAND_GBN', 'BOBN', 'BUBN', 'BEGIN_DE', 'END_DE', 'RNUM', 'ROAD_CD', 'BLDG_LOC', 'BLDG_BOBN', 'BLDG_BUBN', 'STS_GBN', 'SGG_NM'], inplace=True)
df2.dropna(inplace=True)
df2.tail()
# Out:
#       BJDONG_NM                                           ADDRESS  \
# 26603       서교동                 서울특별시 마포구 월드컵로10길 13 , 1층우측 (서교동)
# 26604       신수동                           서울특별시 마포구 독막로 240 (신수동)
# 26605      노고산동              서울특별시 마포구 신촌로 150 102호 (노고산동, 신촌포스빌)
# 26606       공덕동                         서울특별시 마포구 마포대로7길 33 (공덕동)
# 26607       상암동  서울특별시 마포구 상암산로1길 96 상가동 103호 우측(상암동, 상암월드컵파크7단지)
#
#                RA_REGNO RDEALER_NM          CMP_NM     TELNO
# 26603  11440-2015-00119        최지현      리치공인중개사사무소         -
# 26604     92380000-4891        정숙영   성원부동산공인중개사사무소  715-7989
# 26605     92380000-4894        이옥현  포스빌부동산공인중개사사무소  702-2229
# 26606     92380000-4906        이병규  굿모닝부동산공인중개사사무소  711-0509
# 26607     92380000-4959        김은아   월드컵파크공인중개사사무소  373-2323

# %%
# 결측치 확인
df2.isna().sum()
# Out:
# BJDONG_NM     0
# ADDRESS       0
# RA_REGNO      0
# RDEALER_NM    0
# CMP_NM        0
# TELNO         0
# dtype: int64

# %%
df2
# Out:
#       BJDONG_NM                                           ADDRESS  \
# 0          신도림동      서울특별시 구로구 경인로 661 101동 619호(신도림동, 신도림1차푸르지오)
# 1           구로동      서울특별시 구로구 디지털로33길 11 101-1호(구로동, 에이스테크노타워8차)
# 2           구로동                   서울특별시 구로구 구로동로 117  1층 일부 (구로동)
# 3           구로동                      서울특별시 구로구 도림로3길 3 1층 일부(구로동)
# 4           구로동      서울특별시 구로구 새말로 31 롯데아파트상가 108호(구로동, 신도림롯데아파트)
# ...         ...                                               ...
# 26603       서교동                 서울특별시 마포구 월드컵로10길 13 , 1층우측 (서교동)
# 26604       신수동                           서울특별시 마포구 독막로 240 (신수동)
# 26605      노고산동              서울특별시 마포구 신촌로 150 102호 (노고산동, 신촌포스빌)
# 26606       공덕동                         서울특별시 마포구 마포대로7길 33 (공덕동)
# 26607       상암동  서울특별시 마포구 상암산로1길 96 상가동 103호 우측(상암동, 상암월드컵파크7단지)
#
#                RA_REGNO RDEALER_NM          CMP_NM         TELNO
# 0      11500-2022-00106        이동근      라빌공인중개사사무소
# 1      11530-2023-00039        이지흔      타워공인중개사사무소  02-2025-7677
# 2      41190-2022-00036        이창우      아라공인중개사사무소
# 3      11530-2023-00041        조영매      한중공인중개사사무소
# 4          92420000-977         최발      롯데공인중개사사무소      855-8000
# ...                 ...        ...             ...           ...
# 26603  11440-2015-00119        최지현      리치공인중개사사무소             -
# 26604     92380000-4891        정숙영   성원부동산공인중개사사무소      715-7989
# 26605     92380000-4894        이옥현  포스빌부동산공인중개사사무소      702-2229
# 26606     92380000-4906        이병규  굿모닝부동산공인중개사사무소      711-0509
# 26607     92380000-4959        김은아   월드컵파크공인중개사사무소      373-2323
#
# [26608 rows x 6 columns]

# %%
# csv파일로 저장
df2.to_csv('data/서울부동산원본.csv', index=False, encoding='utf-8')
